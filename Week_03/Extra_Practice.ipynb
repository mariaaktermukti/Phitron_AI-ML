# %% [markdown]
# Ques 1:

# %%
import numpy as np

c_array = np.array([0, 20, 37, 100])

f_array = c_array * 1.8 + 32

print("Temperatures in Fahrenheit:", f_array)
# Out:
# Temperatures in Fahrenheit: [ 32.   68.   98.6 212. ]

# %% [markdown]
# Ques 2:

# %%
import numpy as np

lap_array = np.array([75, 88, 92, 80, 79])

print("Shape:", lap_array.shape)
print("Size:", lap_array.size)
print("Data Type:", lap_array.dtype)

lap_minutes = lap_array / 60
print("Lap times in minutes:", lap_minutes)
# Out:
# Shape: (5,)
# Size: 5
# Data Type: int64
# Lap times in minutes: [1.25       1.46666667 1.53333333 1.33333333 1.31666667]
