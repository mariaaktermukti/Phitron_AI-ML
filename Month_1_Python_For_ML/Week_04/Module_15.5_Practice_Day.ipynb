# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('C:/Users/User/Downloads/Practice Day (1).csv', on_bad_lines='skip')
df
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E103      Charlie  22.0  52000.0   1100      92      95      90
# 2       E101        Alice  25.0  50000.0   1200      85      90      88
# 3       E104        David  45.0  80000.0   2500      88      85      89
# 4       E105          Eve  29.0  58000.0   1300      76      79      81
# 5       E106        Frank   NaN  75000.0   2200      90      91      92
# 6       E107        Grace  34.0      NaN   1900      81      83      80
# 7       E108        Heidi  38.0      NaN   1800      84      86      88
# 8       E109         Ivan  26.0  53000.0   1400      95      92      94

# %% [markdown]
# task 1-> Add New Column and Save File

# %%
df['Discounted_Price']= df['Price']*0.9
df
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E103      Charlie  22.0  52000.0   1100      92      95      90
# 2       E101        Alice  25.0  50000.0   1200      85      90      88
# 3       E104        David  45.0  80000.0   2500      88      85      89
# 4       E105          Eve  29.0  58000.0   1300      76      79      81
# 5       E106        Frank   NaN  75000.0   2200      90      91      92
# 6       E107        Grace  34.0      NaN   1900      81      83      80
# 7       E108        Heidi  38.0      NaN   1800      84      86      88
# 8       E109         Ivan  26.0  53000.0   1400      95      92      94
#
#    Discounted_Price
# 0            1080.0
# 1             990.0
# 2            1080.0
# 3            2250.0
# 4            1170.0
# 5            1980.0
# 6            1710.0
# 7            1620.0
# 8            1260.0

# %%
df.to_csv('discounted_products.csv')

# %%
df
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E103      Charlie  22.0  52000.0   1100      92      95      90
# 2       E101        Alice  25.0  50000.0   1200      85      90      88
# 3       E104        David  45.0  80000.0   2500      88      85      89
# 4       E105          Eve  29.0  58000.0   1300      76      79      81
# 5       E106        Frank   NaN  75000.0   2200      90      91      92
# 6       E107        Grace  34.0      NaN   1900      81      83      80
# 7       E108        Heidi  38.0      NaN   1800      84      86      88
# 8       E109         Ivan  26.0  53000.0   1400      95      92      94
#
#    Discounted_Price
# 0            1080.0
# 1             990.0
# 2            1080.0
# 3            2250.0
# 4            1170.0
# 5            1980.0
# 6            1710.0
# 7            1620.0
# 8            1260.0

# %% [markdown]
# task 2-> Check Duplicates and Remove Them

# %%
df
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E103      Charlie  22.0  52000.0   1100      92      95      90
# 2       E101        Alice  25.0  50000.0   1200      85      90      88
# 3       E104        David  45.0  80000.0   2500      88      85      89
# 4       E105          Eve  29.0  58000.0   1300      76      79      81
# 5       E106        Frank   NaN  75000.0   2200      90      91      92
# 6       E107        Grace  34.0      NaN   1900      81      83      80
# 7       E108        Heidi  38.0      NaN   1800      84      86      88
# 8       E109         Ivan  26.0  53000.0   1400      95      92      94
#
#    Discounted_Price
# 0            1080.0
# 1             990.0
# 2            1080.0
# 3            2250.0
# 4            1170.0
# 5            1980.0
# 6            1710.0
# 7            1620.0
# 8            1260.0

# %%
duplicate_count=df.duplicated(subset='EmployeeID').sum()
duplicate_count
# Out:
# np.int64(1)

# %%
df= df.drop_duplicates(subset='EmployeeID')
df
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E103      Charlie  22.0  52000.0   1100      92      95      90
# 3       E104        David  45.0  80000.0   2500      88      85      89
# 4       E105          Eve  29.0  58000.0   1300      76      79      81
# 5       E106        Frank   NaN  75000.0   2200      90      91      92
# 6       E107        Grace  34.0      NaN   1900      81      83      80
# 7       E108        Heidi  38.0      NaN   1800      84      86      88
# 8       E109         Ivan  26.0  53000.0   1400      95      92      94
#
#    Discounted_Price
# 0            1080.0
# 1             990.0
# 3            2250.0
# 4            1170.0
# 5            1980.0
# 6            1710.0
# 7            1620.0
# 8            1260.0

# %%
df.head()
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E103      Charlie  22.0  52000.0   1100      92      95      90
# 3       E104        David  45.0  80000.0   2500      88      85      89
# 4       E105          Eve  29.0  58000.0   1300      76      79      81
# 5       E106        Frank   NaN  75000.0   2200      90      91      92
#
#    Discounted_Price
# 0            1080.0
# 1             990.0
# 3            2250.0
# 4            1170.0
# 5            1980.0

# %% [markdown]
# task 3-> Handle Missing Values

# %%
missing_values= df[['Age','Salary']].isnull().sum()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, 0 to 8
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   EmployeeID        8 non-null      object
#  1   EmployeeName      8 non-null      object
#  2   Age               7 non-null      float64
#  3   Salary            6 non-null      float64
#  4   Price             8 non-null      int64
#  5   Marks1            8 non-null      int64
#  6   Marks2            8 non-null      int64
#  7   Marks3            8 non-null      int64
#  8   Discounted_Price  8 non-null      float64
# dtypes: float64(3), int64(4), object(2)
# memory usage: 640.0+ bytes

# %%
# Fill missing Age with mean age

mean_age= df['Age'].mean()
# print(mean_age)
df.loc[df['Age'].isnull(), 'Age']=mean_age
df[['EmployeeID', 'Age']]
# Out:
#   EmployeeID        Age
# 0       E101  25.000000
# 1       E103  22.000000
# 3       E104  45.000000
# 4       E105  29.000000
# 5       E106  31.285714
# 6       E107  34.000000
# 7       E108  38.000000
# 8       E109  26.000000

# %%
#Drop rows where Salary is missing
df = df[df['Salary'].notnull()]
df
# Out:
#   EmployeeID EmployeeName        Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.000000  50000.0   1200      85      90      88
# 1       E103      Charlie  22.000000  52000.0   1100      92      95      90
# 3       E104        David  45.000000  80000.0   2500      88      85      89
# 4       E105          Eve  29.000000  58000.0   1300      76      79      81
# 5       E106        Frank  31.285714  75000.0   2200      90      91      92
# 8       E109         Ivan  26.000000  53000.0   1400      95      92      94
#
#    Discounted_Price
# 0            1080.0
# 1             990.0
# 3            2250.0
# 4            1170.0
# 5            1980.0
# 8            1260.0

# %% [markdown]
# tast 4-> Apply Statistical Functions

# %%
df = pd.read_csv('C:/Users/User/Downloads/Practice Day (1).csv', on_bad_lines='skip')
df

df['Total_Marks'] = df['Marks1'] + df['Marks2'] + df['Marks3']

df['Mean_Marks'] = df[['Marks1','Marks2','Marks3']].mean(axis=1)
df
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E103      Charlie  22.0  52000.0   1100      92      95      90
# 2       E101        Alice  25.0  50000.0   1200      85      90      88
# 3       E104        David  45.0  80000.0   2500      88      85      89
# 4       E105          Eve  29.0  58000.0   1300      76      79      81
# 5       E106        Frank   NaN  75000.0   2200      90      91      92
# 6       E107        Grace  34.0      NaN   1900      81      83      80
# 7       E108        Heidi  38.0      NaN   1800      84      86      88
# 8       E109         Ivan  26.0  53000.0   1400      95      92      94
#
#    Total_Marks  Mean_Marks
# 0          263   87.666667
# 1          277   92.333333
# 2          263   87.666667
# 3          262   87.333333
# 4          236   78.666667
# 5          273   91.000000
# 6          244   81.333333
# ...

# %%
std_total= df['Total_Marks'].std()
print(std_total)
# Out:
# 14.683702227677838

# %% [markdown]
# task 5-> Histogram, Bar, Scatter, Pie

# %%
df
# Out:
#   EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  Marks3  \
# 0       E101        Alice  25.0  50000.0   1200      85      90      88
# 1       E103      Charlie  22.0  52000.0   1100      92      95      90
# 2       E101        Alice  25.0  50000.0   1200      85      90      88
# 3       E104        David  45.0  80000.0   2500      88      85      89
# 4       E105          Eve  29.0  58000.0   1300      76      79      81
# 5       E106        Frank   NaN  75000.0   2200      90      91      92
# 6       E107        Grace  34.0      NaN   1900      81      83      80
# 7       E108        Heidi  38.0      NaN   1800      84      86      88
# 8       E109         Ivan  26.0  53000.0   1400      95      92      94
#
#    Total_Marks  Mean_Marks
# 0          263   87.666667
# 1          277   92.333333
# 2          263   87.666667
# 3          262   87.333333
# 4          236   78.666667
# 5          273   91.000000
# 6          244   81.333333
# ...

# %%
plt.hist(df['Age'][df['Age'].notnull()], bins=5, color='red', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
plt.show()

# %%
plt.scatter(df['Age'], df['Salary'], marker='o', color='red')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Scatter Plot: Age vs Salary')
plt.show()

# %%
df.columns
# Out:
# Index(['EmployeeID', 'EmployeeName', 'Age', 'Salary', 'Price', 'Marks1',
#        'Marks2', 'Marks3', 'Total_Marks', 'Mean_Marks'],
#       dtype='object')

# %%
new = pd.read_csv('C:\\Users\\User\\Downloads\\discounted_products.csv')
new
# Out:
#    Unnamed: 0 EmployeeID EmployeeName   Age   Salary  Price  Marks1  Marks2  \
# 0           0       E101        Alice  25.0  50000.0   1200      85      90
# 1           1       E103      Charlie  22.0  52000.0   1100      92      95
# 2           2       E101        Alice  25.0  50000.0   1200      85      90
# 3           3       E104        David  45.0  80000.0   2500      88      85
# 4           4       E105          Eve  29.0  58000.0   1300      76      79
# 5           5       E106        Frank   NaN  75000.0   2200      90      91
# 6           6       E107        Grace  34.0      NaN   1900      81      83
# 7           7       E108        Heidi  38.0      NaN   1800      84      86
# 8           8       E109         Ivan  26.0  53000.0   1400      95      92
#
#    Marks3  Discounted_Price
# 0      88            1080.0
# 1      90             990.0
# 2      88            1080.0
# 3      89            2250.0
# 4      81            1170.0
# 5      92            1980.0
# ...

# %%
plt.scatter(new['Price'], new['Discounted_Price'], marker='o', color='red')
plt.xlabel('Price')
plt.ylabel('Discounted Price')
plt.title('Scatter Plot: Price vs Discounted Price')
plt.show()
